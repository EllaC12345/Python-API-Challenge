# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
import json
from scipy.stats import linregress
# !pip install citipy

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 585

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key
    

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q="+ city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | edinburgh of the seven seas
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | talnakh
# Processing Record 4 of Set 1 | mezica
# Processing Record 5 of Set 1 | glace bay
# Processing Record 6 of Set 1 | shangri-la
# City not found. Skipping...
# Processing Record 7 of Set 1 | iskateley
# Processing Record 8 of Set 1 | peace river
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | vorgashor
# Processing Record 12 of Set 1 | pariaman
# Processing Record 13 of Set 1 | adamstown
# Processing Record 14 of Set 1 | ust'-barguzin
# Processing Record 15 of Set 1 | corund
# Processing Record 16 of Set 1 | waitangi
# Processing Record 17 of Set 1 | san luis de la loma
# Processing Record 18 of Set 1 | stanley
# Processing Record 19 of Set 1 | nuku'alofa
# Processing Record 20 of Set 1 | sitka
# ...

# %%
city_data
# Out:
# [{'City': 'edinburgh of the seven seas',
#   'Lat': -37.0676,
#   'Lng': -12.3116,
#   'Max Temp': 12.49,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 14.16,
#   'Country': 'SH',
#   'Date': 1697399161},
#  {'City': 'albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 13.36,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 4.75,
#   'Country': 'US',
#   'Date': 1697399013},
#  {'City': 'talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': -8.77,
#   'Humidity': 92,
#   'Cloudiness': 22,
#   'Wind Speed': 0.63,
#   'Country': 'RU',
#   'Date': 1697399161},
#  {'City': 'mezica',
#   'Lat': 46.5214,
#   'Lng': 14.8544,
#   'Max Temp': 7.66,
#   'Humidity': 99,
#   'Cloudiness': 82,
#   'Wind Speed': 0.67,
#   'Country': 'SI',
#   'Date': 1697399161},
#  {'City': 'glace bay',
#   'Lat': 46.1969,
#   'Lng': -59.957,
#   'Max Temp': 14.94,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 3.13,
#   'Country': 'CA',
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df

# Show Record Count
city_data_df.count()
# Out:
# City          563
# Lat           563
# Lng           563
# Max Temp      563
# Humidity      563
# Cloudiness    563
# Wind Speed    563
# Country       563
# Date          563
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat      Lng  Max Temp  Humidity  \
# 0  edinburgh of the seven seas -37.0676 -12.3116     12.49        91
# 1                       albany  42.6001 -73.9662     13.36        59
# 2                      talnakh  69.4865  88.3972     -8.77        92
# 3                       mezica  46.5214  14.8544      7.66        99
# 4                    glace bay  46.1969 -59.9570     14.94        78
#
#    Cloudiness  Wind Speed Country        Date
# 0         100       14.16      SH  1697399161
# 1         100        4.75      US  1697399013
# 2          22        0.63      RU  1697399161
# 3          82        0.67      SI  1697399161
# 4         100        3.13      CA  1697399161

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 0        edinburgh of the seven seas -37.0676 -12.3116     12.49        91
# 1                             albany  42.6001 -73.9662     13.36        59
# 2                            talnakh  69.4865  88.3972     -8.77        92
# 3                             mezica  46.5214  14.8544      7.66        99
# 4                          glace bay  46.1969 -59.9570     14.94        78
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100       14.16      SH  1697399161
# 1               100        4.75      US  1697399013
# 2                22        0.63      RU  1697399161
# 3                82        0.67      SI  1697399161
# 4               100        3.13      CA  1697399161

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.show()


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values)
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values)
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values)
# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']

# linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plost the points
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.2792952735457001

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df= city_data_df[city_data_df['Lat']>= 0]

# Display sample data
northern_hemi_df.tail()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 556      labrador city  52.9463  -66.9114      5.95        81         100
# 557           mabaruma   8.2000  -59.7833     31.00        63           8
# 560              zabol  32.2500   67.2500     10.36        67           5
# 561           bucerias  20.7500 -105.3333     32.21        70          20
# 562            sonoita  31.8500 -112.8333     35.08        15           0
#
#          Wind Speed Country        Date
# City_ID
# 556            7.72      CA  1697399238
# 557            3.39      GY  1697399238
# 560            4.23      AF  1697399239
# 561            3.60      MX  1697399239
# 562            1.98      MX  1697399239

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat']< 0]

# Display sample data
southern_hemi_df.tail()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 541                namibe -15.1961   12.1522     18.67        73          26
# 549              itaituba  -4.2761  -55.9836     35.09        55          40
# 553      flying fish cove -10.4217  105.6791     25.82        94         100
# 558               springs -26.2500   28.4000     15.87        85         100
# 559              cururupu  -1.8283  -44.8683     29.17        63          53
#
#          Wind Speed Country        Date
# City_ID
# 541            1.97      AO  1697399132
# 549            3.50      BR  1697399237
# 553            3.60      CX  1697399036
# 558            4.52      ZA  1697399238
# 559            2.97      BR  1697399238

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

# linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plost the points
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7387576428671357

# %%
# Linear regression on Northern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

# linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plost the points
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (x_values.mean(), y_values.max()), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5967336521575928

# %% [markdown]
# **Discussion about the linear relationship:**
# in the northen hemisphenere,temperature is negativeky correlated with latitude, as evidenced by a downward slope of the regerssion line and a negativeB.
#  In addition, the R2 is high (.76 ) meaning that changes in latitude can explain changes in Max temperarture.
#
# in the sourthern hemisphere, temperature is positeively correlated with latitude as evidenced by upward slope. the r square is positive and at 59%; which means that the increase in temparature can be explained by increase in latitude for 59% of cases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

# linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plost the points
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (x_values.mean(), y_values.max()), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.046824556139289576

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

# linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plost the points
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (x_values.mean(), y_values.max()), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.016430946123709968

# %% [markdown]
# **Discussion about the linear relationship:**
# in the northen hemisphenere, latitude and humidioty are moderaltely correlated, with a sligt upward curve, and a R2 of .046. this means that only 4% of changes in humidity is due to a change in latitude
#
# in the sourthern hemisphere, we observe lesser correlation with only 1.6 % of varaition in humidity levels that can be explained by a change in latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

# linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plost the points
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (x_values.mean(), y_values.min()), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0580345737601617

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

# linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plost the points
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (x_values.mean(), y_values.max()), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.012749704773967448

# %% [markdown]
# **Discussion about the linear relationship:**
# in both the northen and the southern hemisphere, we observe a small and positive correlation between latitude and cloudiness. In both cases the points are scattered and do not always follow the positive slope. Only 5% and 1% of changes in cloudiness can be explained by a change in latitude for the northern and southern hemisphere respectively.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

# linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plost the points
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.030893757217469564

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

# linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plost the points
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (x_values.mean(), y_values.max()), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.1393142606934083

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
# for the northen Hemisphere, we observe a positive correlation between wind speed and latitide. The plots are centered along the line with an upward slope. However, only 3% of the the chnage in wind speed can be explained by a change in latitude.
#
# in the contrast, in the southern hemisphere,there is a small be negative correlation between wind speed and latitude avidenced by a downward sloping curve. However, this is a weak correlation as the plots are scattered through the graph. In addition, 13% of changes in Wind speed can be explained by changed in latitude.
